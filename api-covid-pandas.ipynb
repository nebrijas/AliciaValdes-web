# %% [markdown]
# # AD3: conexión con la API del COVID19 y análisis con Pandas

# %% [markdown]
# Me conecto a la API https://covid19api.com/

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Alicia Valdés\python.exe -m pip install --upgrade pip' command.
# ...

# %%
pip install numpy
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Alicia Valdés\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
url = "https://api.covid19api.com/countries"

# %%
url
# Out:
# 'https://api.covid19api.com/countries'

# %%
df = pd.read_json("https://api.covid19api.com/countries")

# %% [markdown]
# ## Países

# %%
df
# Out:
#                        Country                       Slug ISO2
# 0                    Gibraltar                  gibraltar   GI
# 1                         Oman                       oman   OM
# 2                       France                     france   FR
# 3                       Jersey                     jersey   JE
# 4                         Mali                       mali   ML
# ..                         ...                        ...  ...
# 243                Puerto Rico                puerto-rico   PR
# 244           Papua New Guinea           papua-new-guinea   PG
# 245  Saint Pierre and Miquelon  saint-pierre-and-miquelon   PM
# 246                Timor-Leste                timor-leste   TL
# 247                 Montenegro                 montenegro   ME
#
# [248 rows x 3 columns]

# %% [markdown]
# ## Datos de España

# %%
df[df["Country"] == "Spain"]
# Out:
#     Country   Slug ISO2
# 141   Spain  spain   ES

# %%
url_rt_es = "https://api.covid19api.com/country/spain/status/confirmed/live"
df_rt_es = pd.read_json(url_rt_es)
df_rt_es
# Out:
#     Country CountryCode Province City CityCode    Lat   Lon     Cases  \
# 0     Spain          ES                         40.46 -3.75         0
# 1     Spain          ES                         40.46 -3.75         0
# 2     Spain          ES                         40.46 -3.75         0
# 3     Spain          ES                         40.46 -3.75         0
# 4     Spain          ES                         40.46 -3.75         0
# ..      ...         ...      ...  ...      ...    ...   ...       ...
# 894   Spain          ES                         40.46 -3.75  12818184
# 895   Spain          ES                         40.46 -3.75  12890002
# 896   Spain          ES                         40.46 -3.75  12890002
# 897   Spain          ES                         40.46 -3.75  12890002
# 898   Spain          ES                         40.46 -3.75  12973615
#
#         Status                      Date
# 0    confirmed 2020-01-22 00:00:00+00:00
# 1    confirmed 2020-01-23 00:00:00+00:00
# ...

# %%
df_rt_es.head()
# Out:
#   Country CountryCode Province City CityCode    Lat   Lon  Cases     Status  \
# 0   Spain          ES                         40.46 -3.75      0  confirmed
# 1   Spain          ES                         40.46 -3.75      0  confirmed
# 2   Spain          ES                         40.46 -3.75      0  confirmed
# 3   Spain          ES                         40.46 -3.75      0  confirmed
# 4   Spain          ES                         40.46 -3.75      0  confirmed
#
#                        Date
# 0 2020-01-22 00:00:00+00:00
# 1 2020-01-23 00:00:00+00:00
# 2 2020-01-24 00:00:00+00:00
# 3 2020-01-25 00:00:00+00:00
# 4 2020-01-26 00:00:00+00:00

# %%
df_rt_es.tail()
# Out:
#     Country CountryCode Province City CityCode    Lat   Lon     Cases  \
# 894   Spain          ES                         40.46 -3.75  12818184
# 895   Spain          ES                         40.46 -3.75  12890002
# 896   Spain          ES                         40.46 -3.75  12890002
# 897   Spain          ES                         40.46 -3.75  12890002
# 898   Spain          ES                         40.46 -3.75  12973615
#
#         Status                      Date
# 894  confirmed 2022-07-04 00:00:00+00:00
# 895  confirmed 2022-07-05 00:00:00+00:00
# 896  confirmed 2022-07-06 00:00:00+00:00
# 897  confirmed 2022-07-07 00:00:00+00:00
# 898  confirmed 2022-07-08 00:00:00+00:00

# %%
grafico_df_rt_es.set_index("Date")["Cases"].plot(title="Casos de Covid19 en España")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 grafico_df_rt_es.set_index("Date")["Cases"].plot(title="Casos de Covid19 en España")
#
# NameError: name 'grafico_df_rt_es' is not defined

# %% [markdown]
# ## Datos de Panamá

# %%
df[df["Country"] == "Panama"]
# Out:
#     Country    Slug ISO2
# 190  Panama  panama   PA

# %%
url_rt_pa ="https://api.covid19api.com/country/Panama/status/confirmed/live"
df_rt_pa = pd.read_json(url_rt_pa)
df_rt_pa
# Out:
#     Country CountryCode Province City CityCode   Lat    Lon   Cases  \
# 0    Panama          PA                         8.54 -80.78       0
# 1    Panama          PA                         8.54 -80.78       0
# 2    Panama          PA                         8.54 -80.78       0
# 3    Panama          PA                         8.54 -80.78       0
# 4    Panama          PA                         8.54 -80.78       0
# ..      ...         ...      ...  ...      ...   ...    ...     ...
# 895  Panama          PA                         8.54 -80.78  925254
# 896  Panama          PA                         8.54 -80.78  925254
# 897  Panama          PA                         8.54 -80.78  925254
# 898  Panama          PA                         8.54 -80.78  932710
# 899  Panama          PA                         8.54 -80.78  932710
#
#         Status                      Date
# 0    confirmed 2020-01-22 00:00:00+00:00
# 1    confirmed 2020-01-23 00:00:00+00:00
# ...

# %%
df_rt_pa.head()
# Out:
#   Country CountryCode Province City CityCode   Lat    Lon  Cases     Status  \
# 0  Panama          PA                         8.54 -80.78      0  confirmed
# 1  Panama          PA                         8.54 -80.78      0  confirmed
# 2  Panama          PA                         8.54 -80.78      0  confirmed
# 3  Panama          PA                         8.54 -80.78      0  confirmed
# 4  Panama          PA                         8.54 -80.78      0  confirmed
#
#                        Date
# 0 2020-01-22 00:00:00+00:00
# 1 2020-01-23 00:00:00+00:00
# 2 2020-01-24 00:00:00+00:00
# 3 2020-01-25 00:00:00+00:00
# 4 2020-01-26 00:00:00+00:00

# %%
df_rt_pa.tail()
# Out:
#     Country CountryCode Province City CityCode   Lat    Lon   Cases  \
# 895  Panama          PA                         8.54 -80.78  925254
# 896  Panama          PA                         8.54 -80.78  925254
# 897  Panama          PA                         8.54 -80.78  925254
# 898  Panama          PA                         8.54 -80.78  932710
# 899  Panama          PA                         8.54 -80.78  932710
#
#         Status                      Date
# 895  confirmed 2022-07-05 00:00:00+00:00
# 896  confirmed 2022-07-06 00:00:00+00:00
# 897  confirmed 2022-07-07 00:00:00+00:00
# 898  confirmed 2022-07-08 00:00:00+00:00
# 899  confirmed 2022-07-10 00:00:00+00:00

# %% [markdown]
# ## Comentarios

# %% [markdown]
# Esta práctica estuvo bastante interesante, ya que como magia los gráficos y datos se muestran con solo ingresar unos códigos.
# Y de acuerdo a las órdenes de nosotros.
# Lo complicado estuvo al momento de ingresar los códigos. En mi caso, no me fue posible introducir códigos ya que me salía ERROR en el "PlOT". Intenté hacerlo de otras maneras y me seguía apareciendo errores distintos. Espero poder corregirlo, porque me
# interesa trabajar con gráficos.
# Dataframe, una nueva manera en mi caso de trabajar con datos, puesto que acostumbro trabajar con excel.
